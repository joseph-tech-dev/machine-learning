# %% [markdown]
# <a href="https://colab.research.google.com/github/joseph-tech-dev/machine-learning/blob/main/Real_vs_ai_image_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
BATCH_SIZE=32
IMAGE_SIZE=256
CHANNELS=3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Images",
    batch_size=BATCH_SIZE,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
)
# Out:
# Found 2522 files belonging to 2 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['ai_images', 'real_images']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
  for i in range(15):
    ax = plt.subplot(3, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[labels_batch[i]])
    plt.axis("off")

# %%
len(dataset)
# Out:
# 79

# %% [markdown]
# 80% Training
# 20% ==> 10% Testing and 10% Validating

# %%
# function to split the Dataset
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):

  if shuffle:
    ds = ds.shuffle(shuffle_size, seed=12)

  # Calculate the sizes of the partitions
  train_size = int(0.8 * len(ds))
  val_size = int(0.1 * len(ds))
  test_size = len(ds) - train_size - val_size

  # Splitting the dataset
  train_ds = ds.take(train_size)
  val_ds = ds.skip(train_size).take(val_size)
  test_ds = ds.skip(train_size + val_size).take(test_size)

  return train_ds, val_ds, test_ds

# %% [markdown]
# Splitting the datasets

# %%
train_ds,val_ds,test_ds = get_dataset_partitions_tf(dataset)

# %%
print(f"Length of Training Dataset: {len(train_ds)}")
print(f"Length of Validation Dataset: {len(val_ds)}")
print(f"Length of Testing Dataset: {len(test_ds)}")
# Out:
# Length of Training Dataset: 63
# Length of Validation Dataset: 7
# Length of Testing Dataset: 9

# %% [markdown]
# Caching and pre-fetching to improve performance

# %%
# caching and prefetcing
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
#

# %% [markdown]
# Rescaling and Resizing
# Incase during prediction the model recieves an image that is not 256 * 256

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    tf.keras.layers.Rescaling(1./255)
])

# %% [markdown]
# Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
])

# %%
# Biulding the model
# Architecture: convolution > pooling
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 2
model = tf.keras.models.Sequential([
    # 1. Define the input explicitly for the model
    tf.keras.layers.Input(shape=input_shape),

    # 2. Preprocessing Layers (should maintain batch dimension)
    resize_and_rescale,
    data_augmentation,

    # 3. Convolutional Layers (Remove input_shape here, Input layer handles it)
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 277,826 (1.06 MB)
#  Trainable params: 277,826 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.7779 - loss: 0.4569 - val_accuracy: 0.7679 - val_loss: 0.4340
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7590 - loss: 0.4785 - val_accuracy: 0.8170 - val_loss: 0.4085
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7806 - loss: 0.4604 - val_accuracy: 0.7768 - val_loss: 0.4572
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.7733 - loss: 0.4572 - val_accuracy: 0.7723 - val_loss: 0.4183
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7785 - loss: 0.4430 - val_accuracy: 0.7812 - val_loss: 0.4212
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7961 - loss: 0.4442 - val_accuracy: 0.8080 - val_loss: 0.4152
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7879 - loss: 0.4299 - val_accuracy: 0.7991 - val_loss: 0.4051
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7850 - loss: 0.4265 - val_accuracy: 0.7545 - val_loss: 0.4270
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8047 - loss: 0.4121 - val_accuracy: 0.8259 - val_loss: 0.3970
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8057 - loss: 0.4152 - val_accuracy: 0.8036 - val_loss: 0.4074
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8073 - loss: 0.4166 - val_accuracy: 0.7857 - val_loss: 0.4198
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8154 - loss: 0.4023 - val_accuracy: 0.7768 - val_loss: 0.4156
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8342 - loss: 0.3689 - val_accuracy: 0.8438 - val_loss: 0.3968
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8204 - loss: 0.3901 - val_accuracy: 0.7589 - val_loss: 0.4274
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8263 - loss: 0.3832 - val_accuracy: 0.7946 - val_loss: 0.4504
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8400 - loss: 0.3816 - val_accuracy: 0.8259 - val_loss: 0.4151
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8067 - loss: 0.3922 - val_accuracy: 0.8170 - val_loss: 0.4098
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8179 - loss: 0.3807 - val_accuracy: 0.8393 - val_loss: 0.3954
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8394 - loss: 0.3697 - val_accuracy: 0.7232 - val_loss: 0.5099
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8168 - loss: 0.4061 - val_accuracy: 0.8125 - val_loss: 0.4034
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8221 - loss: 0.3883 - val_accuracy: 0.8125 - val_loss: 0.3853
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8283 - loss: 0.3770 - val_accuracy: 0.8304 - val_loss: 0.3813
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8153 - loss: 0.3819 - val_accuracy: 0.8259 - val_loss: 0.4154
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8214 - loss: 0.3732 - val_accuracy: 0.8125 - val_loss: 0.4097
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8437 - loss: 0.3595 - val_accuracy: 0.8125 - val_loss: 0.4139
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8232 - loss: 0.3748 - val_accuracy: 0.8125 - val_loss: 0.4323
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8443 - loss: 0.3657 - val_accuracy: 0.8527 - val_loss: 0.3428
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8399 - loss: 0.3582 - val_accuracy: 0.8170 - val_loss: 0.4350
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8443 - loss: 0.3447 - val_accuracy: 0.8304 - val_loss: 0.4123
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8444 - loss: 0.3495 - val_accuracy: 0.8571 - val_loss: 0.3274
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8611 - loss: 0.3429 - val_accuracy: 0.8438 - val_loss: 0.3946
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8463 - loss: 0.3460 - val_accuracy: 0.8482 - val_loss: 0.3679
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8620 - loss: 0.3181 - val_accuracy: 0.8348 - val_loss: 0.3523
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8513 - loss: 0.3442 - val_accuracy: 0.8348 - val_loss: 0.3974
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8523 - loss: 0.3462 - val_accuracy: 0.8259 - val_loss: 0.4310
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8423 - loss: 0.3384 - val_accuracy: 0.8348 - val_loss: 0.4071
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8499 - loss: 0.3327 - val_accuracy: 0.8393 - val_loss: 0.4065
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8812 - loss: 0.2924 - val_accuracy: 0.8438 - val_loss: 0.3887
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8655 - loss: 0.2968 - val_accuracy: 0.8482 - val_loss: 0.3901
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8815 - loss: 0.2912 - val_accuracy: 0.8705 - val_loss: 0.3506
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8765 - loss: 0.2924 - val_accuracy: 0.8795 - val_loss: 0.4209
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8692 - loss: 0.2979 - val_accuracy: 0.8393 - val_loss: 0.4068
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8546 - loss: 0.3196 - val_accuracy: 0.8750 - val_loss: 0.3778
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8641 - loss: 0.2959 - val_accuracy: 0.8214 - val_loss: 0.4132
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8748 - loss: 0.3025 - val_accuracy: 0.8571 - val_loss: 0.4019
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8708 - loss: 0.2994 - val_accuracy: 0.8527 - val_loss: 0.4104
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8694 - loss: 0.2756 - val_accuracy: 0.8661 - val_loss: 0.4217
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8667 - loss: 0.2938 - val_accuracy: 0.8348 - val_loss: 0.3938
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8808 - loss: 0.2700 - val_accuracy: 0.8571 - val_loss: 0.4009
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8878 - loss: 0.2727 - val_accuracy: 0.8616 - val_loss: 0.4722

# %%
acc = history.history["accuracy"]
loss = history.history["loss"]

val_acc = history.history["val_accuracy"]
val_loss = history.history["val_loss"]

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')



plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')

# %%
def predict(model, img):
  img_array = tf.keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)

  predictions = model.predict(img_array)
  predicted_class = class_names[np.argmax(predictions[0])]
  confidence = round(100 * (np.max(predictions[0])), 3)
  return predicted_class, confidence

# %%
# Making Predications
plt.figure(figsize=(15, 15))
for image_batch, labels_batch in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    predicted_class, confidence = predict(model, image_batch[i].numpy())
    actual_class = class_names[labels_batch[i]]
    plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
    plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
